# %%
import pandas as pd

# %%
df = pd.read_csv('final_result.csv', sep='\t')

# %%
df.loc[df['Model'] != 'UCB', 'C'] = 0

# %%
df
# Out:
#       C    Clicks  Iterative    MAP@10    MAP@15    MAP@20     MAP@5  \
# 0   0.0  0.111811       True  0.526253  0.492304  0.465160  0.573244
# 1   0.0  0.071969       True  0.584978  0.554146  0.530175  0.627984
# 2   0.0  0.113386      False  0.515102  0.481702  0.454581  0.558651
# 3   0.0  0.064567      False  0.603015  0.572099  0.545774  0.643102
# 4   0.0  0.114173       True  0.522890  0.489380  0.461550  0.566651
# 5   0.0  0.074646       True  0.581251  0.552599  0.529044  0.620105
# 6   0.0  0.138583      False  0.481983  0.449039  0.423200  0.528824
# 7   0.0  0.081575      False  0.565218  0.538473  0.514621  0.596871
# 8   1.0  0.111811       True  0.525279  0.490594  0.463029  0.569685
# 9   1.0  0.068504       True  0.585093  0.556429  0.533038  0.625381
# 10  1.0  0.124724      False  0.497721  0.465597  0.439127  0.538073
# 11  1.0  0.065669      False  0.589787  0.558427  0.533127  0.628047
# 12  2.0  0.107402       True  0.529762  0.494289  0.465921  0.574787
# ...

# %%
#df = df.drop(list(range(1, 174, 2))).reset_index(drop=True)
#df

# %%
# df.to_csv('final_result.csv', sep='\t', encoding='utf-8', index=False)

# %%
df[(df['Model'] == 'Greedy') & (df['SampleFromAll'] == True)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 
'Recall@5', 'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 
'MAP@15': 'mean', 'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 
'Precision@10': 'mean', 'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 
'R-Precision': 'mean', 'Recall@5': 'mean', 'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean',
                                                                     'Recall@50': 'mean'})
# Out:
#    Iterative     MAP@5    MAP@10    MAP@15    MAP@20    MAP@50      NDCG  \
# 0      False  0.559470  0.516241  0.483123  0.455906  0.349279  0.224324
# 1       True  0.567882  0.525302  0.491568  0.463978  0.360013  0.233142
#
#    Precision@5  Precision@10  Precision@15  Precision@20  Precision@50  \
# 0     0.519055      0.446677      0.398068      0.358630      0.230961
# 1     0.525827      0.456693      0.403990      0.367224      0.241811
#
#    R-Precision  Recall@5  Recall@10  Recall@15  Recall@20  Recall@50
# 0     0.160961  0.037405   0.063629   0.084639   0.101207   0.163064
# 1     0.169505  0.037910   0.065046   0.085826   0.103835   0.171665

# %%
df[(df['Model'] == 'UCB') & (df['Iterative'] == True) & (df['SampleFromAll'] == True)]
# Out:
#       C    Clicks  Iterative    MAP@10    MAP@15    MAP@20     MAP@5  \
# 8   1.0  0.111811       True  0.525279  0.490594  0.463029  0.569685
# 12  2.0  0.107402       True  0.529762  0.494289  0.465921  0.574787
# 24  1.0  0.110236       True  0.527201  0.493545  0.465934  0.571045
# 28  2.0  0.115906       True  0.528105  0.493625  0.465620  0.571664
# 40  1.0  0.112598       True  0.527571  0.493828  0.465776  0.570215
# 44  2.0  0.114488       True  0.521709  0.489267  0.462627  0.565648
# 55  0.5  0.114961       True  0.524862  0.490835  0.463927  0.567948
# 59  1.0  0.111654       True  0.524014  0.491290  0.464612  0.567255
# 63  2.0  0.105669       True  0.529986  0.495618  0.467760  0.574294
# 75  0.5  0.109606       True  0.525718  0.492048  0.464924  0.568730
# 79  1.0  0.113543       True  0.526552  0.492951  0.465744  0.571234
# 83  2.0  0.108976       True  0.532562  0.497095  0.468646  0.579097
#
# ...

# %%
df.groupby(['Model', 'C', 'Iterative', 'SampleFromAll'], as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})
# Out:
#                Model    C  Iterative  SampleFromAll     MAP@5    MAP@10  \
# 0             Greedy  0.0      False          False  0.636387  0.599495
# 1             Greedy  0.0      False           True  0.559470  0.516241
# 2             Greedy  0.0       True          False  0.625411  0.584062
# 3             Greedy  0.0       True           True  0.567882  0.525302
# 4   ThompsonSampling  0.0      False          False  0.613557  0.573595
# 5   ThompsonSampling  0.0      False           True  0.518442  0.474580
# 6   ThompsonSampling  0.0       True          False  0.621474  0.582742
# 7   ThompsonSampling  0.0       True           True  0.561318  0.520612
# 8                UCB  0.5      False          False  0.638286  0.597731
# 9                UCB  0.5      False           True  0.548774  0.502971
# 10               UCB  0.5       True          False  0.631832  0.589725
# 11               UCB  0.5       True           True  0.568339  0.525290
# ...
