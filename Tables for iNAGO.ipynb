# %% [markdown]
# # Research Question 1: Is active learning helping to boost recommendation general performance?

# %% [markdown]
# Table 1. Iterative. Sample from all data

# %%
import pandas as pd
df = pd.read_csv('final_result.csv', sep='\t')
df[(df['Iterative'] == True) & (df['SampleFromAll'] == True)].groupby(['Model', 'C'], as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Model', 'C', 
'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
'Recall@5', 'Recall@10']]


# df[(df['Iterative'] == True) & (df['SampleFromAll'] == True)].groupby(['Model', 'C'], as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
# 'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
# 'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
# 'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
# 'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
# 'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Model', 'C', 
# 'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
# 'Recall@5', 'Recall@10']].to_csv('table1.csv', index=False)
# Out:
#               Model    C  R-Precision      NDCG     MAP@5    MAP@10  \
# 0            Greedy  0.0     0.169505  0.233142  0.567882  0.525302
# 1  ThompsonSampling  0.0     0.167140  0.230464  0.561318  0.520612
# 2               UCB  0.5     0.168059  0.231867  0.568339  0.525290
# 3               UCB  1.0     0.169060  0.233027  0.569887  0.526123
# 4               UCB  2.0     0.168617  0.232875  0.573098  0.528425
#
#    Precision@5  Precision@10  Recall@5  Recall@10
# 0     0.525827      0.456693  0.037910   0.065046
# 1     0.521890      0.453512  0.037526   0.064626
# 2     0.531654      0.457402  0.038300   0.065245
# 3     0.526677      0.455874  0.037898   0.064948
# 4     0.531528      0.457291  0.038263   0.065235

# %% [markdown]
# Table 2. Iterative. Sample from only positive data

# %%
import pandas as pd
df = pd.read_csv('final_result.csv', sep='\t')
df[(df['Iterative'] == True) & (df['SampleFromAll'] == False)].groupby(['Model', 'C'], as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Model', 'C', 
'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
'Recall@5', 'Recall@10']]

# df[(df['Iterative'] == True) & (df['SampleFromAll'] == False)].groupby(['Model', 'C'], as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
# 'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
# 'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
# 'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
# 'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
# 'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Model', 'C', 
# 'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
# 'Recall@5', 'Recall@10']].to_csv('table2.csv', index=False)
# Out:
#               Model    C  R-Precision      NDCG     MAP@5    MAP@10  \
# 0            Greedy  0.0     0.233702  0.301108  0.625411  0.584062
# 1  ThompsonSampling  0.0     0.232349  0.299699  0.621474  0.582742
# 2               UCB  0.5     0.231266  0.300095  0.631832  0.589725
# 3               UCB  1.0     0.232511  0.300145  0.624056  0.583961
# 4               UCB  2.0     0.232289  0.299984  0.625411  0.585460
#
#    Precision@5  Precision@10  Recall@5  Recall@10
# 0     0.580913      0.522677  0.042423   0.075868
# 1     0.582173      0.522268  0.042478   0.075856
# 2     0.588819      0.527874  0.043138   0.076818
# 3     0.581984      0.522803  0.042550   0.075978
# 4     0.582488      0.524126  0.042706   0.076199

# %% [markdown]
# Table 3. Non-Iterative. Sample from all data

# %%
import pandas as pd
df = pd.read_csv('final_result.csv', sep='\t')
df[(df['Iterative'] == False) & (df['SampleFromAll'] == True)].groupby(['Model', 'C'], as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Model', 'C', 
'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
'Recall@5', 'Recall@10']]

# df[(df['Iterative'] == False) & (df['SampleFromAll'] == True)].groupby(['Model', 'C'], as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
# 'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
# 'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
# 'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
# 'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
# 'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Model', 'C', 
# 'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
# 'Recall@5', 'Recall@10']].to_csv('table3.csv', index=False)
# Out:
#               Model    C  R-Precision      NDCG     MAP@5    MAP@10  \
# 0            Greedy  0.0     0.160961  0.224324  0.559470  0.516241
# 1  ThompsonSampling  0.0     0.160909  0.217527  0.518442  0.474580
# 2               UCB  0.5     0.161268  0.222113  0.548774  0.502971
# 3               UCB  1.0     0.161174  0.221170  0.541444  0.498199
# 4               UCB  2.0     0.160291  0.218124  0.531462  0.484496
#
#    Precision@5  Precision@10  Recall@5  Recall@10
# 0     0.519055      0.446677  0.037405   0.063629
# 1     0.470425      0.407276  0.033785   0.057846
# 2     0.499843      0.430551  0.035883   0.061287
# 3     0.498898      0.430394  0.035883   0.061284
# 4     0.482457      0.411055  0.034507   0.058493

# %% [markdown]
# Table 4. Non-Iterative. Sample from only positive data

# %%
import pandas as pd
df = pd.read_csv('final_result.csv', sep='\t')
df[(df['Iterative'] == False) & (df['SampleFromAll'] == False)].groupby(['Model', 'C'], as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Model', 'C', 
'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
'Recall@5', 'Recall@10']]

# df[(df['Iterative'] == False) & (df['SampleFromAll'] == False)].groupby(['Model', 'C'], as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
# 'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
# 'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
# 'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
# 'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
# 'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Model', 'C', 
# 'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
# 'Recall@5', 'Recall@10']].to_csv('table4.csv', index=False)
# Out:
#               Model    C  R-Precision      NDCG     MAP@5    MAP@10  \
# 0            Greedy  0.0     0.223278  0.293907  0.636387  0.599495
# 1  ThompsonSampling  0.0     0.218842  0.285719  0.613557  0.573595
# 2               UCB  0.5     0.221447  0.291819  0.638286  0.597731
# 3               UCB  1.0     0.220472  0.289660  0.626317  0.587666
# 4               UCB  2.0     0.219830  0.288738  0.626614  0.587225
#
#    Precision@5  Precision@10  Recall@5  Recall@10
# 0     0.602961      0.539150  0.044158   0.078547
# 1     0.573165      0.510961  0.042046   0.074824
# 2     0.598583      0.531654  0.043819   0.077472
# 3     0.586835      0.526677  0.043156   0.076987
# 4     0.589291      0.522520  0.043310   0.076412

# %% [markdown]
# # Research Question 2: Is doing active learning iteratively on active set helping recommender system's general performance?

# %% [markdown]
# Table 5. Greedy Algorithm, Sample from all data

# %%
import pandas as pd
df = pd.read_csv('final_result.csv', sep='\t')
df[(df['Model'] == 'Greedy') & (df['SampleFromAll'] == True)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
'Recall@5', 'Recall@10']]

# df[(df['Model'] == 'Greedy') & (df['SampleFromAll'] == True)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
# 'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
# 'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
# 'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
# 'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
# 'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
# 'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
# 'Recall@5', 'Recall@10']].to_csv('table5.csv', index=False)
# Out:
#    Iterative  R-Precision      NDCG     MAP@5    MAP@10  Precision@5  \
# 0      False     0.160961  0.224324  0.559470  0.516241     0.519055
# 1       True     0.169505  0.233142  0.567882  0.525302     0.525827
#
#    Precision@10  Recall@5  Recall@10
# 0      0.446677  0.037405   0.063629
# 1      0.456693  0.037910   0.065046

# %% [markdown]
# Table 6. Greedy Algorithm, Sample from only positive data

# %%
import pandas as pd
df = pd.read_csv('final_result.csv', sep='\t')
df[(df['Model'] == 'Greedy') & (df['SampleFromAll'] == False)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
'Recall@5', 'Recall@10']]

# df[(df['Model'] == 'Greedy') & (df['SampleFromAll'] == False)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
# 'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
# 'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
# 'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
# 'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
# 'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
# 'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
# 'Recall@5', 'Recall@10']].to_csv('table6.csv', index=False)
# Out:
#    Iterative  R-Precision      NDCG     MAP@5    MAP@10  Precision@5  \
# 0      False     0.223278  0.293907  0.636387  0.599495     0.602961
# 1       True     0.233702  0.301108  0.625411  0.584062     0.580913
#
#    Precision@10  Recall@5  Recall@10
# 0      0.539150  0.044158   0.078547
# 1      0.522677  0.042423   0.075868

# %% [markdown]
# Table 7. Thompson Sampling, Sample from all data

# %%
import pandas as pd
df = pd.read_csv('final_result.csv', sep='\t')
df[(df['Model'] == 'ThompsonSampling') & (df['SampleFromAll'] == True)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
'Recall@5', 'Recall@10']]

# df[(df['Model'] == 'ThompsonSampling') & (df['SampleFromAll'] == True)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
# 'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
# 'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
# 'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
# 'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
# 'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
# 'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
# 'Recall@5', 'Recall@10']].to_csv('table7.csv', index=False)
# Out:
#    Iterative  R-Precision      NDCG     MAP@5    MAP@10  Precision@5  \
# 0      False     0.160909  0.217527  0.518442  0.474580     0.470425
# 1       True     0.167140  0.230464  0.561318  0.520612     0.521890
#
#    Precision@10  Recall@5  Recall@10
# 0      0.407276  0.033785   0.057846
# 1      0.453512  0.037526   0.064626

# %% [markdown]
# Table 8. Thompson Sampling, Sample from only positive data

# %%
import pandas as pd
df = pd.read_csv('final_result.csv', sep='\t')
df[(df['Model'] == 'ThompsonSampling') & (df['SampleFromAll'] == False)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
'Recall@5', 'Recall@10']]

# df[(df['Model'] == 'ThompsonSampling') & (df['SampleFromAll'] == False)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
# 'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
# 'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
# 'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
# 'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
# 'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
# 'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
# 'Recall@5', 'Recall@10']].to_csv('table8.csv', index=False)
# Out:
#    Iterative  R-Precision      NDCG     MAP@5    MAP@10  Precision@5  \
# 0      False     0.218842  0.285719  0.613557  0.573595     0.573165
# 1       True     0.232349  0.299699  0.621474  0.582742     0.582173
#
#    Precision@10  Recall@5  Recall@10
# 0      0.510961  0.042046   0.074824
# 1      0.522268  0.042478   0.075856

# %% [markdown]
# Table 9. UCB, C=0.5, Sample from all data

# %%
import pandas as pd
df = pd.read_csv('final_result.csv', sep='\t')
df[(df['Model'] == 'UCB') & (df['SampleFromAll'] == True) & (df['C'] == 0.5)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
'Recall@5', 'Recall@10']]

# df[(df['Model'] == 'UCB') & (df['SampleFromAll'] == True) & (df['C'] == 0.5)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
# 'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
# 'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
# 'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
# 'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
# 'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
# 'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
# 'Recall@5', 'Recall@10']].to_csv('table9.csv', index=False)
# Out:
#    Iterative  R-Precision      NDCG     MAP@5    MAP@10  Precision@5  \
# 0      False     0.161268  0.222113  0.548774  0.502971     0.499843
# 1       True     0.168059  0.231867  0.568339  0.525290     0.531654
#
#    Precision@10  Recall@5  Recall@10
# 0      0.430551  0.035883   0.061287
# 1      0.457402  0.038300   0.065245

# %% [markdown]
# Table 10. UCB, C=0.5, Sample from only positive data

# %%
import pandas as pd
df = pd.read_csv('final_result.csv', sep='\t')
df[(df['Model'] == 'UCB') & (df['SampleFromAll'] == False) & (df['C'] == 0.5)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
'Recall@5', 'Recall@10']]

# df[(df['Model'] == 'UCB') & (df['SampleFromAll'] == False) & (df['C'] == 0.5)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
# 'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
# 'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
# 'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
# 'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
# 'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
# 'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
# 'Recall@5', 'Recall@10']].to_csv('table10.csv', index=False)
# Out:
#    Iterative  R-Precision      NDCG     MAP@5    MAP@10  Precision@5  \
# 0      False     0.221447  0.291819  0.638286  0.597731     0.598583
# 1       True     0.231266  0.300095  0.631832  0.589725     0.588819
#
#    Precision@10  Recall@5  Recall@10
# 0      0.531654  0.043819   0.077472
# 1      0.527874  0.043138   0.076818

# %% [markdown]
# Table 11. UCB, C=1.0, Sample from all data

# %%
import pandas as pd
df = pd.read_csv('final_result.csv', sep='\t')
df[(df['Model'] == 'UCB') & (df['SampleFromAll'] == True) & (df['C'] == 1.0)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
'Recall@5', 'Recall@10']]

# df[(df['Model'] == 'UCB') & (df['SampleFromAll'] == True) & (df['C'] == 1.0)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
# 'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
# 'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
# 'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
# 'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
# 'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
# 'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
# 'Recall@5', 'Recall@10']].to_csv('table11.csv', index=False)
# Out:
#    Iterative  R-Precision      NDCG     MAP@5    MAP@10  Precision@5  \
# 0      False     0.161174  0.221170  0.541444  0.498199     0.498898
# 1       True     0.169060  0.233027  0.569887  0.526123     0.526677
#
#    Precision@10  Recall@5  Recall@10
# 0      0.430394  0.035883   0.061284
# 1      0.455874  0.037898   0.064948

# %% [markdown]
# Table 12. UCB, C=1.0, Sample from only positive data

# %%
import pandas as pd
df = pd.read_csv('final_result.csv', sep='\t')
df[(df['Model'] == 'UCB') & (df['SampleFromAll'] == False) & (df['C'] == 1.0)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
'Recall@5', 'Recall@10']]

# df[(df['Model'] == 'UCB') & (df['SampleFromAll'] == True) & (df['C'] == 1.0)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
# 'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
# 'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
# 'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
# 'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
# 'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
# 'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
# 'Recall@5', 'Recall@10']].to_csv('table12.csv', index=False)
# Out:
#    Iterative  R-Precision      NDCG     MAP@5    MAP@10  Precision@5  \
# 0      False     0.220472  0.289660  0.626317  0.587666     0.586835
# 1       True     0.232511  0.300145  0.624056  0.583961     0.581984
#
#    Precision@10  Recall@5  Recall@10
# 0      0.526677  0.043156   0.076987
# 1      0.522803  0.042550   0.075978

# %% [markdown]
# Table 13. UCB, C=2.0, Sample from all data

# %%
import pandas as pd
df = pd.read_csv('final_result.csv', sep='\t')
df[(df['Model'] == 'UCB') & (df['SampleFromAll'] == True) & (df['C'] == 2.0)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
'Recall@5', 'Recall@10']]

# df[(df['Model'] == 'UCB') & (df['SampleFromAll'] == True) & (df['C'] == 2.0)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
# 'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
# 'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
# 'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
# 'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
# 'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
# 'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
# 'Recall@5', 'Recall@10']].to_csv('table13.csv', index=False)
# Out:
#    Iterative  R-Precision      NDCG     MAP@5    MAP@10  Precision@5  \
# 0      False     0.160291  0.218124  0.531462  0.484496     0.482457
# 1       True     0.168617  0.232875  0.573098  0.528425     0.531528
#
#    Precision@10  Recall@5  Recall@10
# 0      0.411055  0.034507   0.058493
# 1      0.457291  0.038263   0.065235

# %% [markdown]
# Table 14. UCB, C=2.0, Sample from only positive data

# %%
import pandas as pd
df = pd.read_csv('final_result.csv', sep='\t')
df[(df['Model'] == 'UCB') & (df['SampleFromAll'] == False) & (df['C'] == 2.0)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
'Recall@5', 'Recall@10']]

# df[(df['Model'] == 'UCB') & (df['SampleFromAll'] == False) & (df['C'] == 2.0)].groupby('Iterative', as_index=False)['MAP@5', 'MAP@10', 'MAP@15', 'MAP@20', 'MAP@50', 'NDCG',
# 'Precision@5', 'Precision@10', 'Precision@15', 'Precision@20', 'Precision@50', 'R-Precision', 'Recall@5',
# 'Recall@10', 'Recall@15', 'Recall@20', 'Recall@50'].agg({'MAP@5': 'mean', 'MAP@10': 'mean', 'MAP@15': 'mean', 
# 'MAP@20': 'mean', 'MAP@50': 'mean', 'NDCG': 'mean', 'Precision@5': 'mean', 'Precision@10': 'mean', 
# 'Precision@15': 'mean', 'Precision@20': 'mean', 'Precision@50': 'mean', 'R-Precision': 'mean', 'Recall@5': 'mean',
# 'Recall@10': 'mean', 'Recall@15': 'mean', 'Recall@20': 'mean', 'Recall@50': 'mean'})[['Iterative', 
# 'R-Precision', 'NDCG', 'MAP@5', 'MAP@10', 'Precision@5', 'Precision@10',
# 'Recall@5', 'Recall@10']].to_csv('table14.csv', index=False)
# Out:
#    Iterative  R-Precision      NDCG     MAP@5    MAP@10  Precision@5  \
# 0      False     0.219830  0.288738  0.626614  0.587225     0.589291
# 1       True     0.232289  0.299984  0.625411  0.585460     0.582488
#
#    Precision@10  Recall@5  Recall@10
# 0      0.522520  0.043310   0.076412
# 1      0.524126  0.042706   0.076199
